# %% [markdown]
# # Visualisation des données
# ## observation des features pertinents pour la prédiction en consomation

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import ast
import sklearn as skl
import seaborn as sns

# %%
### importation du dataframe final

df = pd.read_csv('building-energy-benchmarking_final.csv',sep= ',')
df.head()
# Out:
#    Unnamed: 0  OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0           0              1      2015  NonResidential               Hotel
# 1           1              2      2015  NonResidential               Hotel
# 2           2              3      2015  NonResidential               Hotel
# 3           3              5      2015  NonResidential               Hotel
# 4           4              8      2015  NonResidential               Hotel
#
#   TaxParcelIdentificationNumber  CouncilDistrictCode Neighborhood  YearBuilt  \
# 0                     659000030                    7     DOWNTOWN       1927
# 1                     659000220                    7     DOWNTOWN       1996
# 2                     659000475                    7     DOWNTOWN       1969
# 3                     659000640                    7     DOWNTOWN       1926
# 4                     659000970                    7     DOWNTOWN       1980
#
#    NumberofBuildings  ...  SiteEnergyUse(kBtu)  SteamUse(kBtu)  \
# 0                1.0  ...            6981428.0       2023032.0
# 1                1.0  ...            8354235.0             0.0
# 2                1.0  ...           73130656.0      19660404.0
# 3                1.0  ...           28229320.0      23458518.0
# 4                1.0  ...           14829099.0             0.0
#
#    Electricity(kWh)  NaturalGas(therms) TotalGHGEmissions  \
# 0         1080307.0             12724.0            249.43
# 1         1144563.0             44490.0            263.51
# 2        14583930.0             37099.0           2061.48
# 3          811521.0             20019.0           1936.34
# 4         1777841.0             87631.0            507.70
#
#   GHGEmissionsIntensity   Latitude   Longitude         Address  ZipCode
# 0                  2.64  47.612190 -122.337997   405 OLIVE WAY  98101.0
# 1                  2.38  47.613106 -122.333358     724 PINE ST  98101.0
# 2                  1.92  47.613349 -122.337699    1900 5TH AVE  98101.0
# 3                 31.38  47.614216 -122.336609  620 STEWART ST  98101.0
# 4                  4.02  47.613754 -122.340924   401 LENORA ST  98121.0
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Observtion des différentes réparations
#
#     observation des différentes variables afin de déterminer des features pertinents pour la prédiction

# %%
fig, axs = plt.subplots(2, 2,figsize = (30,30))

a = df.groupby('BuildingType').size()
laba = a.keys()

axs[0, 0].pie(a,labels = laba, autopct='%1.1f%%')
axs[0, 0].set_title('Répartition des différents types de bâtiments')


axs[0,1].hist(df['YearBuilt'],bins = 30,color = 'y')
axs[0,1].set_title('histogramme de la répartition des années de constructions des bâtiments')
axs[0,1].set_xlabel('année de construction')
axs[0,1].set_ylabel('nombre de bâtiments')


axs[1,0].scatter(df['Latitude'],df['Longitude'],color = 'g') 
axs[1,0].set_title('Répartition géographique des bâtiments')
axs[1,0].set_xlabel('Latitude')
axs[1,0].set_ylabel('Longitude')

b = df.groupby('PrimaryPropertyType').size()
labb = b.keys()
axs[1,1].pie(b,labels = labb,autopct='%1.1f%%',labeldistance = 1.2)
axs[1,1].set_title('pie chart des types de propriétés')
plt.show()

# %% [markdown]
# ### Observation des corrélations des différents features avec les variables 'TotalGHGEmissions' et 'SiteEnergyUse(kBtu)'

# %%
### On effectue dans un premier temps une corrélation entre les variables numériques

df_num = df.select_dtypes(include = ['float64','int64'])


df_num.corr(method='spearman').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm

#             background-color:  #dbdcde;
#             color:  #000000;
#         }#T_d9a70_row3_col15,#T_d9a70_row5_col7,#T_d9a70_row5_col9,#T_d9a70_row12_col10{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }#T_d9a70_row3_col16,#T_d9a70_row8_col3,#T_d9a70_row17_col9{
#             background-color:  #dddcdc;
#             color:  #000000;
#         }#T_d9a70_row3_col17,#T_d9a70_row12_col5,#T_d9a70_row19_col5{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_d9a70_row3_col19,#T_d9a70_row17_col3,#T_d9a70_row17_col6,#T_d9a70_row21_col6,#T_d9a70_row21_col15{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_d9a70_row3_col20,#T_d9a70_row14_col6{
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }#T_d9a70_row4_col2,#T_d9a70_row7_col2,#T_d9a70_row8_col2,#T_d9a70_row9_col2,#T_d9a70_row13_col2,#T_d9a70_row14_col2,#T_d9a70_row21_col2{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_d9a70_row4_col5,#T_d9a70_row22_col5{
#             backgrou

# %% [markdown]
# Pour un coefficient de corrélation nettement inférieur à 0.60 on peut considérer que la colonne ne constituera pas un feature interressant pour la prédiction des variables.
#
# On peut retenir les features suivants pour la prédiction de la variable 'TotalGHGEmissions':
#
# - 'LargestPropertyUseTypeGFA'
# - 'SiteEUI(kBtu/sf)	'
# - 'SourceEUI(kBtu/sf)'
# - 'SiteEnergyUse(kBtu)'
# - 'Electricity(kWh)'
# - 'NaturalGas(therms)'
# - 'GHGEmissionsIntensity'
# - 'PropertyGFAtotal'
# - 'PropertyGFABuilding(s)'
#
# On peut retenir les features suivants pour la prédiction de la variable 'SiteEnergyUse(kBtu)':
#
# - 'LargestPropertyUseTypeGFA'
# - 'SiteEUI(kBtu/sf)'
# - 'SourceEUI(kBtu/sf)'
# - 'Electricity(kWh)'
# - 'TotalGHGEmissions'
# - 'PropertyGFATotal'
# - 'PropertyGFABuilding(s)'

# %% [markdown]
# ### Recherche des colonnes non-numériques pertinentes pour les prédiction de rejet de CO2 et de consommation electrique

# %%
df_non_num = df.select_dtypes(include = ['object'])
df_non_num.head()
list_non_num = df_non_num.columns
print(list_non_num)
# Out:
# Index(['BuildingType', 'PrimaryPropertyType', 'TaxParcelIdentificationNumber',
#        'Neighborhood', 'ListOfAllPropertyUseTypes', 'LargestPropertyUseType',
#        'Address'],
#       dtype='object')

# %%
### recherche de corrélations entre variables non numériques et les variables à prédire

fig, ax =plt.subplots(2,1)



ax[0].sns.catplot(x=df['BuildingType'], y=df['SiteEnergyUse(kBtu)'], data=df, height=10, aspect=2, kind='bar')
#f.fig.suptitle('Consommation électrique en fonction du type de bâtiment')

ax[1].sns.catplot(x=df['TotalGHGEmissions'], y=df['SiteEnergyUse(kBtu)'], data=df, height=10, aspect=2, kind='bar',ax=ax[1])
#g.fig.suptitle('Emissions carbone en fonction du type de bâtiment')

fig.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-3d0a018b1109> in <module>
#       5
#       6
# ----> 7 ax[0,0].sns.catplot(x=df['BuildingType'], y=df['SiteEnergyUse(kBtu)'], data=df, height=10, aspect=2, kind='bar')
#       8 #f.fig.suptitle('Consommation électrique en fonction du type de bâtiment')
#       9
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
